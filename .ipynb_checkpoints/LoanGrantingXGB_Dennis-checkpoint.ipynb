# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from xgboost import plot_importance
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from numpy import column_stack
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
from scipy import stats

# %%
df_loan_table = pd.read_csv('loan_table.csv', header = 0, sep=',', quotechar='"')

# %%
# df_loan_table

# %%
df_borrow_table = pd.read_csv('borrower_table.csv', header = 0, sep=',', quotechar='"')

# %%
# df_borrow_table

# %%
df_merged = df_borrow_table.merge(df_loan_table, on='loan_id', how='left')

# %%
df_merged.shape
# Out:
# (101100, 16)

# %%
# number of rows to work with(bank granted loans)
loan_granted = 0
loan_not_granted = 0
for index, row in df_merged.iterrows():
    if row['loan_granted'] == 1:
        loan_granted +=1
    elif row['loan_granted'] == 0:
        loan_not_granted +=1

# %%
print("# of loans granted by bank(Usable): " + str(loan_granted))
print("# of loans not granted by bank(No Y Data): " + str(loan_not_granted))
# Out:
# # of loans granted by bank(Usable): 47654
# # of loans not granted by bank(No Y Data): 53446

# %%
#only look at cases when loan_granted = 1 else NA
df_merged = df_merged[df_merged['loan_granted'] == 1]

# %%
#change loan repaid to sep out and drop that and granted(all 1)
df_y = df_merged['loan_repaid']
df_x = df_merged.drop(columns=['loan_repaid', 'loan_granted'])
print(df_x.shape)
print(df_y.shape)
# for col in df_x.columns:
#     print(col)
# Out:
# (47654, 14)
# (47654,)

# %%
#change all to np.nan for XGB implicit missing value handling
df_x[df_x == float('nan')] = np.nan

# %%
# gcc = 0
# ngc = 0
# for index, row in df_x.iterrows():
#     if row['loan_granted'] == 1:
#         gcc +=1
#     elif row['loan_granted'] == 0:
#         ngc +=1
# print(gcc)
# print(ngc)
# print(gcc +ngc)

# %%
# df_x['Year'] = df_x.date.str[:4]
#dont need year all 2012
df_x['Month'] = df_x.date.str[5:7]
df_x['Day'] = df_x.date.str[8:10]
df_x = df_x.drop(columns=['date'])

# %%
for col in df_x.columns:
    print(col)
# Out:
# loan_id
# is_first_loan
# fully_repaid_previous_loans
# currently_repaying_other_loans
# total_credit_card_limit
# avg_percentage_credit_card_limit_used_last_year
# saving_amount
# checking_amount
# is_employed
# yearly_salary
# age
# dependent_number
# loan_purpose
# Month
# Day

# %%
#try OHEing as well, might lead to more precise results
#logically since day/month are ordinal they shouldn't have to be one
#hot encoded as they should share a relationship(e.g. month 01-12) but 
#the relationship may be hard for XGB model to understand... so test w/ both

# %%
#OHE Month/Day to test post mid proj check here.

# %%
#check which input features are string types/non-integers so I know which ones I need
#to one hot encode for use in XGB
print("is_first_loan", type(df_x.is_first_loan.iloc[1]))
print("fully_repaid_previous_loans", type(df_x.fully_repaid_previous_loans.iloc[1]))
print("currently_repaying_other_loans", type(df_x.currently_repaying_other_loans.iloc[1]))
print("total_credit_card_limit", type(df_x.total_credit_card_limit.iloc[1]))
print("avg_percentage_credit_card_limit_used_last_year", type(df_x.avg_percentage_credit_card_limit_used_last_year.iloc[1]))
print("saving_amount", type(df_x.saving_amount.iloc[1]))
print("checking_amount", type(df_x.checking_amount.iloc[1]))
print("is_employed", type(df_x.is_employed.iloc[1]))
print("yearly_salary", type(df_x.yearly_salary.iloc[1]))
print("age", type(df_x.age.iloc[1]))
print("dependent_number", type(df_x.dependent_number.iloc[1]))
print("loan_purpose", type(df_x.loan_purpose.iloc[1]))
# print("loan_granted", type(df_x.loan_granted.iloc[1]))
print("Month", type(df_x.Month.iloc[1]))
print("Day", type(df_x.Day.iloc[1]))
# Out:
# is_first_loan <class 'numpy.int64'>
# fully_repaid_previous_loans <class 'numpy.float64'>
# currently_repaying_other_loans <class 'numpy.float64'>
# total_credit_card_limit <class 'numpy.int64'>
# avg_percentage_credit_card_limit_used_last_year <class 'numpy.float64'>
# saving_amount <class 'numpy.int64'>
# checking_amount <class 'numpy.int64'>
# is_employed <class 'numpy.int64'>
# yearly_salary <class 'numpy.int64'>
# age <class 'numpy.int64'>
# dependent_number <class 'numpy.int64'>
# loan_purpose <class 'str'>
# Month <class 'str'>
# Day <class 'str'>

# %%
df_x['Day'] = (df_x['Day']).astype(int)
df_x['Month'] = (df_x['Month']).astype(int)

# %%
df_x.shape
# Out:
# (47654, 15)

# %%
df_x
# Out:
#         loan_id  is_first_loan  fully_repaid_previous_loans  \
# 2        135565              1                          NaN
# 5        423171              1                          NaN
# 7        200139              1                          NaN
# 8        991294              0                          1.0
# 9        875332              0                          1.0
# 10       954215              1                          NaN
# 11       778076              1                          NaN
# 13        73441              0                          1.0
# 16       249377              1                          NaN
# 17       387504              0                          1.0
# 21       127290              1                          NaN
# 22       496672              1                          NaN
# 23       873777              1                          NaN
# 31       277463              1                          NaN
# 35       443443              1                          NaN
# 39       378620              1                          NaN
# 40       216233              0                          1.0
# 42        69571              0                          1.0
# 45       666770              0                          1.0
# 47       331569              1                          NaN
# 49        93216              1                          NaN
# 51       576438              1                          NaN
# 52       223013              0                          1.0
# 53       594632              0                          1.0
# 54       196917              0                          1.0
# 55       329106              1                          NaN
# 58        17908              1                          NaN
# 63       234705              0                          1.0
# 65       520296              1                          NaN
# 66       858386              1                          NaN
# ...         ...            ...                          ...
# 101037   905412              0                          1.0
# 101039   743574              0                          1.0
# 101041   348849              1                          NaN
# 101042   959127              1                          NaN
# 101047   675729              0                          1.0
# 101048   603009              0                          1.0
# 101051   995579              0                          1.0
# 101052   265412              1                          NaN
# 101054   287754              0                          1.0
# 101057   939577              0                          1.0
# 101059   752892              0                          1.0
# 101060   751039              0                          1.0
# 101066   788521              1                          NaN
# 101067   847704              1                          NaN
# 101068   229429              1                          NaN
# 101073   596228              0                          1.0
# 101074   837863              0                          1.0
# 101076   832885              1                          NaN
# 101078   846445              0                          1.0
# 101081   106237              0                          1.0
# 101082   867078              1                          NaN
# 101083    21405              0                          1.0
# 101085   352484              1                          NaN
# 101086   631580              1                          NaN
# 101088    17749              0                          0.0
# 101089   697542              1                          NaN
# 101090    20065              0                          1.0
# 101096   590712              1                          NaN
# 101098   551027              0                          1.0
# 101099   761999              1                          NaN
#
#         currently_repaying_other_loans  total_credit_card_limit  \
# 2                                  NaN                     6900
# 5                                  NaN                     6100
# 7                                  NaN                     4000
# 8                                  0.0                     7000
# 9                                  0.0                     4300
# 10                                 NaN                     7000
# 11                                 NaN                     4900
# 13                                 0.0                     3900
# 16                                 NaN                     5500
# 17                                 0.0                     5300
# 21                                 NaN                        0
# 22                                 NaN                     4500
# 23                                 NaN                     5100
# 31                                 NaN                     8000
# 35                                 NaN                     2000
# 39                                 NaN                     5900
# 40                                 0.0                     4100
# 42                                 1.0                     2900
# 45                                 0.0                     2700
# 47                                 NaN                     1100
# 49                                 NaN                     6700
# 51                                 NaN                      700
# 52                                 0.0                     6200
# 53                                 1.0                     3000
# 54                                 0.0                     9100
# 55                                 NaN                     3900
# 58                                 NaN                     1400
# 63                                 0.0                     4800
# 65                                 NaN                     4700
# 66                                 NaN                     6100
# ...                                ...                      ...
# 101037                             0.0                     8400
# 101039                             0.0                     3900
# 101041                             NaN                      500
# 101042                             NaN                     2500
# 101047                             0.0                     6800
# 101048                             0.0                     6100
# 101051                             0.0                     7500
# 101052                             NaN                     3800
# 101054                             0.0                     2300
# 101057                             0.0                     4600
# 101059                             0.0                     2300
# 101060                             1.0                     4200
# 101066                             NaN                     2300
# 101067                             NaN                     2100
# 101068                             NaN                     3400
# 101073                             0.0                     1900
# 101074                             0.0                     4100
# 101076                             NaN                     5000
# 101078                             1.0                     2900
# 101081                             0.0                     4500
# 101082                             NaN                     4700
# 101083                             1.0                     3700
# 101085                             NaN                     5900
# 101086                             NaN                     2300
# 101088                             0.0                     5900
# 101089                             NaN                     2800
# 101090                             0.0                     3000
# 101096                             NaN                     3800
# 101098                             0.0                     7000
# 101099                             NaN                     2300
#
#         avg_percentage_credit_card_limit_used_last_year  saving_amount  \
# 2                                                  0.82           2085
# 5                                                  0.53           6163
# 7                                                  0.57            602
# 8                                                  0.52           2575
# 9                                                  0.83            722
# 10                                                 0.64           2113
# 11                                                 0.60            460
# 13                                                 0.77            989
# 16                                                 0.59           1154
# 17                                                 0.69           1172
# 21                                                  NaN            707
# 22                                                 0.65           3981
# 23                                                 0.30           4755
# 31                                                 0.47           3048
# 35                                                 0.44            275
# 39                                                 0.84           1781
# 40                                                 0.99           2678
# 42                                                 0.62            996
# 45                                                 0.97           4674
# 47                                                 0.81             24
# 49                                                 0.56           6520
# 51                                                 0.90            501
# 52                                                 0.75            510
# 53                                                 0.51           1054
# 54                                                 0.62           2738
# 55                                                 0.56           4299
# 58                                                 0.63            489
# 63                                                 0.87            618
# 65                                                 0.80            483
# 66                                                 0.38           1398
# ...                                                 ...            ...
# 101037                                             0.57            875
# 101039                                             0.90           2538
# 101041                                             0.74           1180
# 101042                                             0.92           1677
# 101047                                             0.36           2725
# 101048                                             0.76           4429
# 101051                                             0.48           1326
# 101052                                             0.39            242
# 101054                                             0.83           1360
# 101057                                             0.71           1007
# 101059                                             0.92           2494
# 101060                                             0.82           3255
# 101066                                             0.58           1247
# 101067                                             0.89            888
# 101068                                             0.81           4849
# 101073                                             0.65           4226
# 101074                                             0.69           1143
# 101076                                             0.81           3955
# 101078                                             0.62            957
# 101081                                             0.73           2773
# 101082                                             0.54           1964
# 101083                                             0.91           1258
# 101085                                             0.77           3120
# 101086                                             0.66           1506
# 101088                                             0.71           2696
# 101089                                             0.82           1485
# 101090                                             0.67            635
# 101096                                             0.70            340
# 101098                                             0.82            354
# 101099                                             0.47           2999
#
#         checking_amount  is_employed  yearly_salary  age  dependent_number  \
#
# 53           investment      5   22
# 54           investment     12    7
# 55                other      7   31
# 58      emergency_funds      3   29
# 63                 home      4   10
# 65             business     10   11
# 66           investment      6    4
# ...                 ...    ...  ...
# 101037             home      5   25
# 101039            other      1   19
# 101041             home     12   19
# 101042       investment      8   21
# 101047            other      5    2
# 101048             home      7    9
# 101051            other     12   11
# 101052       investment      3    7
# 101054             home      8   13
# 101057       investment      9    4
# 101059             home      5   24
# 101060             home     11   21
# 101066             home      7    4
# 101067  emergency_funds      6   20
# 101068             home     10   25
# 101073             home     12   12
# 101074            other      5    1
# 101076             home      3    5
# 101078  emergency_funds      6    5
# 101081  emergency_funds      7   27
# 101082             home      8    1
# 101083            other      1    2
# 101085  emergency_funds      8   30
# 101086  emergency_funds     10   29
# 101088         business      7   12
# 101089            other      3   27
# 101090         business     12    4
# 101096         business      5   17
# 101098       investment      8   23
# 101099             home      6   20
#
# [47654 rows x 15 columns]

# %%
one_hot = pd.get_dummies(df_x['loan_purpose'])
df_x = df_x.drop(columns=['loan_purpose', 'loan_id'])
df_x = df_x.join(one_hot)

# %%
df_x.shape
# Out:
# (47654, 18)

# %%
df_x
# Out:
#         is_first_loan  fully_repaid_previous_loans  \
# 2                   1                          NaN
# 5                   1                          NaN
# 7                   1                          NaN
# 8                   0                          1.0
# 9                   0                          1.0
# 10                  1                          NaN
# 11                  1                          NaN
# 13                  0                          1.0
# 16                  1                          NaN
# 17                  0                          1.0
# 21                  1                          NaN
# 22                  1                          NaN
# 23                  1                          NaN
# 31                  1                          NaN
# 35                  1                          NaN
# 39                  1                          NaN
# 40                  0                          1.0
# 42                  0                          1.0
# 45                  0                          1.0
# 47                  1                          NaN
# 49                  1                          NaN
# 51                  1                          NaN
# 52                  0                          1.0
# 53                  0                          1.0
# 54                  0                          1.0
# 55                  1                          NaN
# 58                  1                          NaN
# 63                  0                          1.0
# 65                  1                          NaN
# 66                  1                          NaN
# ...               ...                          ...
# 101037              0                          1.0
# 101039              0                          1.0
# 101041              1                          NaN
# 101042              1                          NaN
# 101047              0                          1.0
# 101048              0                          1.0
# 101051              0                          1.0
# 101052              1                          NaN
# 101054              0                          1.0
# 101057              0                          1.0
# 101059              0                          1.0
# 101060              0                          1.0
# 101066              1                          NaN
# 101067              1                          NaN
# 101068              1                          NaN
# 101073              0                          1.0
# 101074              0                          1.0
# 101076              1                          NaN
# 101078              0                          1.0
# 101081              0                          1.0
# 101082              1                          NaN
# 101083              0                          1.0
# 101085              1                          NaN
# 101086              1                          NaN
# 101088              0                          0.0
# 101089              1                          NaN
# 101090              0                          1.0
# 101096              1                          NaN
# 101098              0                          1.0
# 101099              1                          NaN
#
#         currently_repaying_other_loans  total_credit_card_limit  \
# 2                                  NaN                     6900
# 5                                  NaN                     6100
# 7                                  NaN                     4000
# 8                                  0.0                     7000
# 9                                  0.0                     4300
# 10                                 NaN                     7000
# 11                                 NaN                     4900
# 13                                 0.0                     3900
# 16                                 NaN                     5500
# 17                                 0.0                     5300
# 21                                 NaN                        0
# 22                                 NaN                     4500
# 23                                 NaN                     5100
# 31                                 NaN                     8000
# 35                                 NaN                     2000
# 39                                 NaN                     5900
# 40                                 0.0                     4100
# 42                                 1.0                     2900
# 45                                 0.0                     2700
# 47                                 NaN                     1100
# 49                                 NaN                     6700
# 51                                 NaN                      700
# 52                                 0.0                     6200
# 53                                 1.0                     3000
# 54                                 0.0                     9100
# 55                                 NaN                     3900
# 58                                 NaN                     1400
# 63                                 0.0                     4800
# 65                                 NaN                     4700
# 66                                 NaN                     6100
# ...                                ...                      ...
# 101037                             0.0                     8400
# 101039                             0.0                     3900
# 101041                             NaN                      500
# 101042                             NaN                     2500
# 101047                             0.0                     6800
# 101048                             0.0                     6100
# 101051                             0.0                     7500
# 101052                             NaN                     3800
# 101054                             0.0                     2300
# 101057                             0.0                     4600
# 101059                             0.0                     2300
# 101060                             1.0                     4200
# 101066                             NaN                     2300
# 101067                             NaN                     2100
# 101068                             NaN                     3400
# 101073                             0.0                     1900
# 101074                             0.0                     4100
# 101076                             NaN                     5000
# 101078                             1.0                     2900
# 101081                             0.0                     4500
# 101082                             NaN                     4700
# 101083                             1.0                     3700
# 101085                             NaN                     5900
# 101086                             NaN                     2300
# 101088                             0.0                     5900
# 101089                             NaN                     2800
# 101090                             0.0                     3000
# 101096                             NaN                     3800
# 101098                             0.0                     7000
# 101099                             NaN                     2300
#
#         avg_percentage_credit_card_limit_used_last_year  saving_amount  \
# 2                                                  0.82           2085
# 5                                                  0.53           6163
# 7                                                  0.57            602
# 8                                                  0.52           2575
# 9                                                  0.83            722
# 10                                                 0.64           2113
# 11                                                 0.60            460
# 13                                                 0.77            989
# 16                                                 0.59           1154
# 17                                                 0.69           1172
# 21                                                  NaN            707
# 22                                                 0.65           3981
# 23                                                 0.30           4755
# 31                                                 0.47           3048
# 35                                                 0.44            275
# 39                                                 0.84           1781
# 40                                                 0.99           2678
# 42                                                 0.62            996
# 45                                                 0.97           4674
# 47                                                 0.81             24
# 49                                                 0.56           6520
# 51                                                 0.90            501
# 52                                                 0.75            510
# 53                                                 0.51           1054
# 54                                                 0.62           2738
# 55                                                 0.56           4299
# 58                                                 0.63            489
# 63                                                 0.87            618
# 65                                                 0.80            483
# 66                                                 0.38           1398
# ...                                                 ...            ...
# 101037                                             0.57            875
# 101039                                             0.90           2538
# 101041                                             0.74           1180
# 101042                                             0.92           1677
# 101047                                             0.36           2725
# 101048                                             0.76           4429
# 101051                                             0.48           1326
# 101052                                             0.39            242
# 101054                                             0.83           1360
# 101057                                             0.71           1007
# 101059                                             0.92           2494
# 101060                                             0.82           3255
# 101066                                             0.58           1247
# 101067                                             0.89            888
# 101068                                             0.81           4849
# 101073                                             0.65           4226
# 101074                                             0.69           1143
# 101076                                             0.81           3955
# 101078                                             0.62            957
# 101081                                             0.73           2773
# 101082                                             0.54           1964
# 101083                                             0.91           1258
# 101085                                             0.77           3120
# 101086                                             0.66           1506
# 101088                                             0.71           2696
# 101089                                             0.82           1485
# 101090                                             0.67            635
# 101096                                             0.70            340
# 101098                                             0.82            354
# 101099                                             0.47           2999
#
#         checking_amount  is_employed  yearly_salary  age  dependent_number  \
#
# 49          3   20         0                0     1           0      0
# 51          8    3         0                0     0           1      0
# 52          9   27         0                1     0           0      0
# 53          5   22         0                0     0           1      0
# 54         12    7         0                0     0           1      0
# 55          7   31         0                0     0           0      1
# 58          3   29         0                1     0           0      0
# 63          4   10         0                0     1           0      0
# 65         10   11         1                0     0           0      0
# 66          6    4         0                0     0           1      0
# ...       ...  ...       ...              ...   ...         ...    ...
# 101037      5   25         0                0     1           0      0
# 101039      1   19         0                0     0           0      1
# 101041     12   19         0                0     1           0      0
# 101042      8   21         0                0     0           1      0
# 101047      5    2         0                0     0           0      1
# 101048      7    9         0                0     1           0      0
# 101051     12   11         0                0     0           0      1
# 101052      3    7         0                0     0           1      0
# 101054      8   13         0                0     1           0      0
# 101057      9    4         0                0     0           1      0
# 101059      5   24         0                0     1           0      0
# 101060     11   21         0                0     1           0      0
# 101066      7    4         0                0     1           0      0
# 101067      6   20         0                1     0           0      0
# 101068     10   25         0                0     1           0      0
# 101073     12   12         0                0     1           0      0
# 101074      5    1         0                0     0           0      1
# 101076      3    5         0                0     1           0      0
# 101078      6    5         0                1     0           0      0
# 101081      7   27         0                1     0           0      0
# 101082      8    1         0                0     1           0      0
# 101083      1    2         0                0     0           0      1
# 101085      8   30         0                1     0           0      0
# 101086     10   29         0                1     0           0      0
# 101088      7   12         1                0     0           0      0
# 101089      3   27         0                0     0           0      1
# 101090     12    4         1                0     0           0      0
# 101096      5   17         1                0     0           0      0
# 101098      8   23         0                0     0           1      0
# 101099      6   20         0                0     1           0      0
#
# [47654 rows x 18 columns]

# %%
# #OHE loan_purpose
# lp_label_encoder = LabelEncoder()
# lp_feature = lp_label_encoder.fit_transform(df_x.loan_purpose.iloc[:].values)

# #print(lp_feature)
# lp_feature = lp_feature.reshape(df_x.shape[0], 1)
# #print(lp_feature)
# onehot_encoder = OneHotEncoder(sparse = False)
# lp_feature = onehot_encoder.fit_transform(lp_feature)
# # print(type(lp_feature))
# print(df_x.loan_purpose.nunique())
# print(lp_feature.shape)

# %%
# #need to convert pandas series' for our already numeric features into numpy arrays so we can stack 
# #them onto the encoded_features so that all features are in one 2d array
# is_first_loan = df_x.is_first_loan.values
# fully_repaid_previous_loans = df_x.fully_repaid_previous_loans.values
# currently_repaying_other_loans = df_x.currently_repaying_other_loans.values
# total_credit_card_limit = df_x.total_credit_card_limit.values
# avg_percentage_credit_card_limit_used_last_year = df_x.avg_percentage_credit_card_limit_used_last_year.values
# saving_amount = df_x.saving_amount.values
# checking_amount = df_x.checking_amount.values
# is_employed = df_x.is_employed.values
# yearly_salary = df_x.yearly_salary.values
# age = df_x.age.values
# dependent_number = df_x.dependent_number.values
# # loan_granted = df_x.loan_granted.values
# Month = df_x.Month.values
# Day = df_x.Day.values

# %%
# #df_x = 16 w/ 1 for id(remove in model) and 1 for loan_purpose, remove = 14, lp_OHE'd = 5, 14+5 = 19 so it works
# columns = []
# columns.append(lp_feature)
# columns.append(is_first_loan)
# columns.append(fully_repaid_previous_loans)
# columns.append(currently_repaying_other_loans)
# columns.append(total_credit_card_limit)
# columns.append(avg_percentage_credit_card_limit_used_last_year)
# columns.append(saving_amount)
# columns.append(checking_amount)
# columns.append(is_employed)
# columns.append(yearly_salary)
# columns.append(age)
# columns.append(dependent_number)
# # columns.append(loan_granted)
# columns.append(Month)
# columns.append(Day)
# encoded_feats = column_stack(columns)
# print(encoded_feats.shape)
# print(df_x.shape)

# %%
#split whole dataset, but in train set only train when loan_granted=1 and drop loan_granted, in test set drop 
#loan_granted and loan_repaid, predict and change predicted values to loan_granted then check against loan_repaid
random_seed = 9
t_s = .33
X_train, X_test, y_train, y_test = train_test_split(df_x, df_y, test_size = t_s, random_state = random_seed)

# %%
model = XGBClassifier()
kfold = StratifiedKFold(n_splits=4, shuffle=True, random_state=random_seed)
param_grid = {'n_estimators': [120, 240, 360, 480], #random int btwn 100 and 500 - removed
              'learning_rate': stats.uniform(0.01, 0.08), #.01 + loc, range of .01+/-.08
              'max_depth': [2, 4, 6, 8], #tree depths to check
              'colsample_bytree': stats.uniform(0.3, 0.7) #btwn .1 and 1.0    
}
rand_search = RandomizedSearchCV(model, param_distributions = param_grid, scoring = 'f1_micro', n_iter = 3, n_jobs=-1, verbose = 10, cv=kfold)
rand_result = rand_search.fit(X_train, y_train)
print("Best: %f using %s" % (rand_result.best_score_, rand_result.best_params_))
best_XGB_parameters = rand_result.best_estimator_
# Out:
# Fitting 4 folds for each of 3 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done   3 out of  12 | elapsed:    6.0s remaining:   18.3s
# [Parallel(n_jobs=-1)]: Done   5 out of  12 | elapsed:    7.3s remaining:   10.2s
# [Parallel(n_jobs=-1)]: Done   7 out of  12 | elapsed:    8.7s remaining:    6.2s
# [Parallel(n_jobs=-1)]: Done   9 out of  12 | elapsed:   10.5s remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:   12.6s finished
# Best: 0.922952 using {'colsample_bytree': 0.6629912723790092, 'learning_rate': 0.05541377202997041, 'max_depth': 2, 'n_estimators': 360}

# %%
from sklearn.metrics import accuracy_score
best_XGB_parameters.fit(X_train, y_train)
predictions = best_XGB_parameters.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print(accuracy * 100.0)
# Out:
# 92.1594811140786
# C:\Users\denni\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
#since only doing cases where loan_granted = 1, any time y_test = 0 dock a point, any time y_test = 1, add a point
bank_score = 0
cnt = 0
for value in y_test:
    if value == 1:
        bank_score += 1
        cnt += 1
    elif value == 0:
        bank_score -= 1
        cnt += 1
print("Bank score = " + str(bank_score))
# Out:
# Bank score = 4558

# %%
xgb_score = 0
cnt = 0
for index, value in enumerate(predictions):
    if value == 1:
        if y_test.iloc[index] == predictions[index]:
            xgb_score += 1
        else:
            xgb_score -=1
        cnt += 1
    elif value == 0:
        cnt += 1
print("Bank score = " + str(bank_score))

print("XGB score = " + str(xgb_score))
print(cnt)
# Out:
# Bank score = 4558
# XGB score = 8909
# 15726

# %%
from matplotlib import pyplot
from xgboost import plot_tree
#feature importances
plot_importance(best_XGB_parameters)
pyplot.show()

# %%
#decision tree
import matplotlib
plot_tree(best_XGB_parameters, num_trees=4, rankdir = 'LR')
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(150, 100)
fig.savefig('tree.png')
pyplot.show()
